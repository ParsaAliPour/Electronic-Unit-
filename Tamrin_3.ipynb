# %%
a=int(input("enter a num : "))
if a>0 :
    print("a is positive")

if a>100 :
    print("a is positive va bozorgtar az 100 ")

if a% 2==0 :
    print("a is  positive va zoje va bozorgtar az 100")
    
else:
    print("a isn't  positive va zoje va bozorgtar az 100")
